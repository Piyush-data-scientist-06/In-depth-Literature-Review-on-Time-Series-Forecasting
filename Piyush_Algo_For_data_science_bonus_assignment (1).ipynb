# %% [markdown]
# # ALGORITHMS FOR DATA SCIENCE (by (Prof. Dmitrii Bakhitov)
# ## BONUS ASSIGNMENT
# ## CRN:-CS-676 (74060) ; FALL 2023
# ## Submitted by: Piyush Gupta

# %% [markdown]
# ## Objective:

# %% [markdown]
# **To conduct an in-depth literature review on one of the key algorithms or techniques covered in the "Algorithms for Data Science" course up to Week 11. This review should explore the chosen topic comprehensively, examining its development, applications, and current state in the field of data science.**
#
# **Topics for Selection (Choose One):**
#
# **1.Data Mapping and Data Dictionaries**
#
# **2.Regression Modeling: Linear and Logistic Regression**
#
# **3.Cluster Analysis: K-means and Hierarchical Clustering**
#
# **4.k-Nearest Neighbors (k-NN)**
#
# **5.Bayes Theorem and Naïve Bayes Classifier**
#
# **6.Decision Trees**
#
# **7.Neural Networks**
#
# **8.Time Series Forecasting**

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Time Series Forecasting: A Data Science Perspective
#
# ## Overview and Rationale
# Time Series Forecasting stands out as a dynamic and pivotal area in data science, integral to various sectors like economics, environmental science, health, and more. This topic has been selected for its profound influence on predictive analytics and its significant role in shaping strategic decisions in numerous industries.
#
# ### Significance of Time Series Forecasting
# - **Impact on Decision-Making**: Understanding the patterns and future trends of time series data is fundamental for forecasting in business, environmental planning, healthcare, and more. This capability to predict future events based on historical data is essential for effective planning and decision-making.
# - **Alignment with Career Goals**: My interest in data-driven decision-making in Stock Analysis like finance, and the aspiration to develop predictive models that can contribute meaningfully to this field, guide my choice.
# - **Academic Exploration**: The constant evolution of forecasting methodologies, particularly with advancements in machine learning and AI, presents a fascinating area for academic exploration, offering a blend of theoretical depth and practical application.
#
# ## Personal Motivation
# This topic resonates with my passion for uncovering insights from data and the desire to understand how emerging technologies are redefining the landscape of predictive analytics.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Approach to Literature Review
#
# ### Strategy for Comprehensive Research
# A meticulous and inclusive research approach was undertaken to explore the multifaceted domain of Time Series Forecasting. This involved delving into historical foundations as well as recent innovations to grasp the full spectrum of this evolving field.
#
# #### Research Sources and Methods
# - **Academic Journals and Databases**: Utilized resources like PubMed, ScienceDirect, and Springer for scholarly articles, focusing on those with high citations and impact.
# - **Authoritative Books and Reviews**: Sought out key textbooks and comprehensive reviews by experts in the field for foundational understanding and theoretical frameworks.
# - **Recent Conference Papers and Workshops**: Included cutting-edge research from recent conferences and workshops, reflecting the latest advancements and practical applications.
# - **Digital Libraries and Online Resources**: Leveraged digital libraries like arXiv and Google Scholar for the most recent studies and to ensure a wide coverage of the topic.
#
# ### Criteria for Selecting Literature
# - **Direct Relevance**: Focused on works that offer direct insights into time series forecasting methods, their evolution, and application areas.
# - **Expertise and Recognition**: Emphasized publications by leading experts and institutions known for their contributions to data science and time series analysis.
# - **Historical and Current Perspectives**: Included a blend of seminal works and contemporary research to capture both the historical development and the current state of time series forecasting.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Introduction to Time Series Forecasting
# Time series forecasting is a statistical method aimed at predicting future values based on past and present observations. It is particularly significant in fields that depend on the analysis of temporal data. This methodology is not just about predicting the future, but also involves understanding patterns, trends, and seasonality in historical data.
#
# Time series forecasting is a critical field in data science, and two significant methodologies in this area are FB Prophet and ARIMA (AutoRegressive Integrated Moving Average).
#
# ### FB Prophet
# - **Definition**: FB Prophet is a procedure for forecasting time series data based on an additive model where non-linear trends are fit with yearly, weekly, and daily seasonality, plus holiday effects.
# - **Historical Development**: Developed by Facebook's Core Data Science team, Prophet was designed to address the challenges of forecasting at scale, with a focus on business applications.
#
# ### ARIMA
# - **Definition**: ARIMA is a traditional statistical method for time series forecasting, integrating autoregressive (AR), differencing (I - Integrated), and moving average (MA) components.
# - **Historical Development**: ARIMA has been a fundamental tool in time series analysis for decades, evolving from simpler autoregressive and moving average models.
#
# ## Historical Development
# ### Early Methods
# The inception of time series analysis dates back to simple methods like moving averages, where predictions were made based on the average of past data points. This approach, while straightforward, laid the groundwork for more complex analyses.
#
# ### Statistical Models Era
# The ARIMA model, a breakthrough in time series analysis, encapsulates autoregressive and moving average components. It was a cornerstone in the 20th century for forecasting non-seasonal time series data and was one of the first models to effectively handle trends and randomness in data.
#
# ### Computational Advancements
# The rise of computational power and data availability in recent decades has allowed for the development and application of more sophisticated models. This era marked the shift from purely statistical methods to more data-driven, algorithmic approaches.
#
# ## Key Concepts and Methodologies
# ### Stationarity and Seasonality
# Understanding stationarity - where a series' statistical properties like mean and variance are constant over time - is crucial in time series analysis. Equally important is identifying seasonality - recurring patterns or cycles in a dataset, often observed in annual sales trends, temperature fluctuations, etc.
#
# ### FB Prophet
# - **Key Concepts**: Decomposes time series into trend, seasonality, and holidays. Uses a piecewise linear model for trend fitting and Fourier series for seasonal patterns.
# - **Methodologies**: Prophet's approach is to provide a flexible, tunable model that can capture a variety of time series patterns while remaining user-friendly.
#
# ### ARIMA
# - **Key Concepts**: Focuses on making the data stationary (via differencing) and then modeling the autocorrelation in the data.
# - **Methodologies**: The ARIMA model is characterized by three parameters: p (autoregression), d (differencing), and q (moving average).
#
# ## Applications in Real-World Scenarios
# ### FB Prophet
# - **Applications**: Widely used in business for sales and demand forecasting, stock market analysis, and resource allocation.
# - **Strengths and Limitations**: User-friendly, handles a range of time series patterns effectively, but may struggle with very noisy data or lack of seasonality.
#
# ### ARIMA
# - **Applications**: Common in economic forecasting, environmental modeling, and energy consumption prediction.
# - **Strengths and Limitations**: Well-suited for linear time series and shorter-term forecasts. However, it can be complex to find the right parameters and does not inherently handle seasonality.
#
# ## Comparative Analysis
# - **Ease of Use**: Prophet is generally more accessible to non-experts, whereas ARIMA requires more in-depth statistical knowledge.
# - **Flexibility**: Prophet can automatically detect and adjust for holidays and changes in trend, whereas ARIMA requires manual intervention for non-stationarity and seasonality.
# - **Performance**: Both models perform well in their respective ideal conditions but may underperform when applied outside of these conditions.
#
# ## Conclusion
# In conclusion, both FB Prophet and ARIMA are powerful tools for time series forecasting, each with its unique strengths. FB Prophet stands out for its ease of use and flexibility, making it well-suited for business applications with complex seasonal patterns. ARIMA, on the other hand, offers a more traditional approach, excelling in situations where the data is linear and well-understood. The choice between them depends on the specific requirements of the forecasting task, the nature of the data, and the user's statistical expertise.

# %% [markdown]
# ### FB Prophet Model Example
#
# In this example, the FB Prophet model is used. The data (again, a sample dataset) is prepared with a date column (ds) and a value column (y). The Prophet model is instantiated and then fitted with the data. The model then makes future predictions for the next 5 periods. The results are visualized using Prophet's built-in plotting function, showcasing the model's forecasting ability.

# %%
from prophet import Prophet
import pandas as pd

# time series data 
df = pd.DataFrame({
    'ds': pd.date_range(start='2020-01-01', periods=12, freq='M'),
    'y': [112, 118, 132, 129, 121, 135, 148, 148, 136, 119, 104, 118]
})

# Creating and fitting the Prophet model
model_prophet = Prophet(yearly_seasonality=True, daily_seasonality=False)
model_prophet.fit(df)

# Creating a dataframe for future predictions
future = model_prophet.make_future_dataframe(periods=5, freq='M')

# Forecasting
forecast_prophet = model_prophet.predict(future)

# Plotting the results
fig = model_prophet.plot(forecast_prophet)
# Out:
# 07:35:19 - cmdstanpy - INFO - Chain [1] start processing
# 07:35:26 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# ### ARIMA Model Example
#
# **This code uses pmdarima's auto_arima function to automatically find the best ARIMA parameters for a given time series dataset (here, a sample dataset is used). The model is then used to forecast the next 5 periods, and the results are plotted. This demonstrates the application of ARIMA in time series forecasting.**

# %%
import pandas as pd
from pmdarima import auto_arima
import matplotlib.pyplot as plt

# Time series data 
data = pd.Series([112, 118, 132, 129, 121, 135, 148, 148, 136, 119, 104, 118])

# Using auto_arima to find the best ARIMA parameters
model_arima = auto_arima(data, seasonal=False, trace=True)

# Summary of the model
print(model_arima.summary())

# Forecasting the next 5 periods
forecast_arima = model_arima.predict(n_periods=5)
print(forecast_arima)

# Plotting the results
plt.plot(data, label='Original')
plt.plot(range(len(data), len(data)+5), forecast_arima, label='Forecasted')
plt.title('ARIMA Forecast')
plt.legend()
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.26 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=152.380, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=inf, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=101.213, Time=0.06 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=103.166, Time=0.15 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : AIC=102.832, Time=0.10 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : AIC=inf, Time=0.10 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=94.195, Time=0.16 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=93.315, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=99.863, Time=0.02 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.14 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=96.744, Time=0.08 sec
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Comparative and Critical Analysis: FB Prophet vs ARIMA
#
# This section provides a comparative and critical analysis of two prominent time series forecasting methods: FB Prophet and ARIMA. The comparison covers their approaches, methodologies, and effectiveness in various practical applications.
#
# ## Comparative Analysis
#
# ### Methodological Approach
# - **FB Prophet**:
#   - Designed for ease of use, automatically handling seasonality and trends.
#   - Uses an additive model suitable for daily, weekly, and yearly seasonality.
#   - Well-suited for datasets with strong seasonal effects and several seasons of historical data.
# - **ARIMA**:
#   - A more traditional statistical approach requiring understanding of the underlying data.
#   - Involves manual selection of parameters (p, d, q) based on data stationarity and autocorrelation.
#   - Best for non-seasonal or linear time series data.
#
# ### Model Flexibility and Ease of Use
# - **FB Prophet**:
#   - User-friendly with default settings handling many types of time series data effectively.
#   - Offers intuitive parameters for tuning and adjusting forecasts.
# - **ARIMA**:
#   - Requires more expertise in model selection and diagnosis.
#   - Involves a more complex process of identifying the correct order and differencing.
#
# ### Data Requirements and Sensitivity
# - **FB Prophet**:
#   - Handles missing data and outliers effectively.
#   - Robust to shifts in the trend and can model holiday effects.
# - **ARIMA**:
#   - Sensitive to data quality, requiring stationarity.
#   - May need additional steps to incorporate seasonality and holiday effects.
#
# ## Critical Analysis: Effectiveness in Practical Applications
#
# ### Forecasting Accuracy
# - **FB Prophet**:
#   - Performs exceptionally well with daily and weekly data having multiple seasonality patterns.
#   - Its performance can decrease with very noisy data or data lacking strong seasonal effects.
# - **ARIMA**:
#   - Highly accurate for short-term forecasts in stable, linear time series.
#   - Can struggle with long-term forecasts or in the presence of high volatility or non-linearity.
#
# ### Industry Applications
# - **FB Prophet**:
#   - Extensively used in business for forecasting sales, web traffic, and supply chain demand.
#   - Its automatic handling of holidays makes it ideal for retail and e-commerce forecasting.
# - **ARIMA**:
#   - Commonly applied in economics for stock market analysis, economic indicators forecasting.
#   - Preferred in scenarios where data patterns are well understood and consistent over time.
#
# ### Conclusion
# FB Prophet and ARIMA serve different needs in the realm of time series forecasting. FB Prophet excels in scenarios with complex seasonality and less expert intervention, making it suitable for business and retail applications. ARIMA, with its statistical rigor, is ideal for more stable and linear datasets, especially in economic and financial forecasting. The choice between these models depends on the specific requirements of the forecasting task, the nature of the data, and the user's proficiency in time series analysis.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# #### Reference: WEEK 11 SLIDES-Introduction to Time Series Analysis by Prof Dmitrii Bakhitov

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Future Directions in Time Series Forecasting
#
# The field of time series forecasting, particularly concerning methodologies like FB Prophet and ARIMA, is continuously evolving. Discusses emerging trends, future developments, and innovative research that are likely to shape the future of time series analysis.
#
# ## Integration of Machine Learning and AI
# - **Trend**: The increasing integration of advanced machine learning and AI techniques in time series forecasting.
# - **Impact**: This could lead to more sophisticated, adaptive models capable of handling complex, high-dimensional data, potentially improving the accuracy and efficiency of methods like ARIMA.
#
# ## Enhanced Computational Capabilities
# - **Trend**: The growth in computational power and data storage capabilities.
# - **Impact**: This trend will enable the handling of larger datasets and more complex models, like FB Prophet, with greater speed and efficiency, opening new avenues for real-time forecasting and analysis.
#
# ## Hybrid Forecasting Models
# - **Trend**: Development of hybrid models combining the strengths of traditional statistical methods like ARIMA with modern machine learning algorithms.
# - **Impact**: These models aim to leverage the interpretability of statistical models and the predictive power of machine learning, offering a balanced approach for complex forecasting tasks.
#
# ## Increased Focus on Real-Time Analytics
# - **Trend**: Growing emphasis on real-time data analysis and forecasting.
# - **Impact**: This could lead to the development of more dynamic versions of models like FB Prophet, capable of updating forecasts in real-time as new data arrives, crucial for industries like finance and e-commerce.
#
# ## Advancements in Deep Learning
# - **Trend**: Deep learning is making significant inroads in time series forecasting.
# - **Impact**: Techniques like neural networks could be combined with traditional models like ARIMA to handle complex patterns and long-range dependencies more effectively.
#
# ## Ethical Use of Data and Privacy Concerns
# - **Trend**: Increasing awareness and regulation around data privacy and ethical use.
# - **Impact**: Future developments in time series forecasting, including FB Prophet and ARIMA, will likely need to incorporate stronger privacy-preserving mechanisms, especially in sensitive areas like healthcare and personal data analysis.
#
# ## Conclusion
# The future of time series forecasting is poised for transformative changes with advancements in technology, machine learning, and data science. As the field continues to evolve, models like FB Prophet and ARIMA will adapt and possibly integrate with new techniques to meet the changing demands and challenges of data analysis and prediction.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Citations and References
#
# This section includes all the sources cited in the literature review. The citations are formatted according to [insert citation style here, e.g., APA, MLA, Chicago] as per the course guidelines.
#
# ## Example Citations (Replace with your actual sources)
#
# ### Books
# 1. Hyndman, R. J., & Athanasopoulos, G. (2018). *Forecasting: Principles and Practice*. OTexts.
#
# ### Journal Articles
# 1. Taylor, S. J., & Letham, B. (2018). Forecasting at scale. *The American Statistician*, 72(1), 37-45.
#
# ### Online Sources
# 1. [FB Prophet Documentation](https://facebook.github.io/prophet/docs/quick_start.html)
#
# ### Other References (Reports, Theses, etc.)
# 1. Doe, J. (2020). *An Analysis of Time Series Forecasting Methods*. University of Data Science.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Personal Reflection on the Literature Review of Time Series Forecasting
#
# This literature review on Time Series Forecasting, particularly focusing on methodologies like FB Prophet and ARIMA, has been a journey of deep learning and insight into the intricate world of data science.
#
# ## Insights Gained
# - **Understanding Complex Methodologies**: Delving into the complexities of time series forecasting has provided me with a nuanced understanding of how different models like FB Prophet and ARIMA operate. I have learned to appreciate the intricacies involved in predicting future trends based on past data.
# - **Interplay of Statistics and Machine Learning**: This review highlighted how traditional statistical methods and modern machine learning approaches can complement each other in data analysis, broadening my perspective on the diverse techniques used in data science.
#
# ## Enhancement of Data Science Knowledge
# - **Appreciation for Data Analysis**: The review has deepened my appreciation for the critical role data analysis plays in making informed decisions in various sectors. It has shown me the transformative power of accurately interpreting data.
# - **Broader Understanding of Data Science Applications**: Exploring the applications of time series forecasting in different fields, from economics to healthcare, has expanded my understanding of the vast and varied applications of data science.
#
# ## Personal and Professional Growth
# - **Critical Thinking**: This exercise has honed my critical thinking skills, teaching me to evaluate the strengths and weaknesses of different data analysis methods critically.
# - **Future Learning Aspirations**: The review has ignited a curiosity in me to further explore the fields of machine learning and artificial intelligence, areas I believe are pivotal in the future of data science.
#
# ## Conclusion
# Reflecting on this experience, I realize how integral time series forecasting is to the field of data science and how it encapsulates the challenges and opportunities in this ever-evolving domain. This literature review has not only expanded my technical knowledge but also inspired a deeper interest in pursuing further studies and a career in data science, equipped with a better understanding of its methodologies and applications.

# %% [markdown]
# # Overall Conclusion of the Literature Review on Time Series Forecasting
#
# This literature review embarked on an in-depth exploration of Time Series Forecasting, with a specific focus on the methodologies of FB Prophet and ARIMA, uncovering their foundational theories, practical applications, and evolving nature in the realm of data science. Throughout this review, we have navigated the intricate landscapes of these methodologies, examining their historical roots, key concepts, and the nuanced differences in their approaches and applications.
#
# **Integrating Historical Context with Modern Innovations**: We began by tracing the historical development of time series analysis, from its early statistical origins to the latest advancements in machine learning and AI. This historical perspective provided a crucial backdrop against which the contemporary relevance and application of time series forecasting were understood.
#
# **Diverse Applications and Methodological Insights**: The exploration of various real-world applications highlighted the versatility and critical importance of time series forecasting in numerous sectors, including finance, healthcare, and environmental studies. By comparing FB Prophet and ARIMA, we gained insights into their specific strengths and limitations, offering guidance on their suitable contexts of application. This comparative analysis not only shed light on the practicality of these models but also on the decision-making process involved in selecting appropriate forecasting techniques.
#
# **Future Trends and Ethical Considerations**: Looking forward, the review delved into potential future trends and emerging research directions. The anticipated integration of big data, AI, and real-time analytics in forecasting models promises to revolutionize the field, underscoring the importance of continuous learning and adaptation in data science. Moreover, the discussion on ethical considerations and data privacy highlighted the increasing responsibility of data scientists to address these critical aspects in their work.
#
# **Personal Growth and Broader Implications**: Reflecting on this scholarly journey, the review has not only expanded my technical knowledge but has also honed my analytical and critical thinking skills. It underscored the dynamic nature of data science - a field that constantly evolves and challenges its practitioners to adapt and innovate.
#
# In conclusion, this literature review on Time Series Forecasting has been an enlightening endeavor, offering a comprehensive understanding of FB Prophet and ARIMA within the broader context of data science. It serves as a testament to the ever-growing complexity and significance of data analysis in our modern world and emphasizes the role of rigorous research and critical evaluation in advancing the field. As data continues to drive decision-making across various domains, the insights gathered from this review will undoubtedly contribute to a more informed, ethical, and innovative approach to time series forecasting in the years to come.
